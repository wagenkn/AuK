# %% [markdown]
# # Lösen von Rekurrenzgleichungen
#
# #### 1.
#
# >   $$
#     2^{\log_4 n} = n^{\log_4 2} = n^{\frac{1}{2}} = \sqrt{n}
#     $$
#
# #### 2.
#
# >   $$
#     \begin{align*}
#     \\
#     T(n) &= 3 \cdot T \left(\frac{n}{4} \right) + n \\
#     T(n) &= 3 \cdot (3 \cdot T \left(\frac{n}{16} \right) + n) + n \\
#     T(n) &= 9 \cdot T \left(\frac{n}{16} \right) + 4n \\
#     T(n) &= 9 \cdot \left(3 \cdot T \left(\frac{n}{64} \right) + n \right) + 4n \\
#     T(n) &= 27 \cdot T \left(\frac{n}{64} \right) + 13n \\
#     T(n) &= 27 \cdot \left(3 \cdot T \left(\frac{n}{256} \right) + n \right) + 13n \\
#     T(n) &= 81 \cdot T \left(\frac{n}{256} \right) + 40n \\
#     T(n) &= 3^i \cdot T \left(\frac{n}{4^i} \right) + \frac{3^i - 1}{2} \cdot n \\
#     \\
#     T \left(\frac{n}{4^i} \right) & = T(1) \\
#     \frac{n}{4^i} &= 1 \\
#     n &= 4^i \\
#     i &= \log_4 n
#     \\
#     T(n) &= 3^{\log_4 n} \cdot T \left(\frac{n}{4^{\log_4 n}} \right) + \frac{3^{\log_4 n} - 1}{2} \cdot n \\
#     T(n) &= n^{\log_4 3} \cdot T(1) + \frac{n^{\log_4 3} - 1}{2} \cdot n \\
#     T(n) &= n^{\log_4 3} \cdot 1 + \frac{n^{\log_4 3} - 1}{2} \cdot n \\
#     T(n) &= n^{\log_4 3} + \frac{n^{\log_4 3} - 1}{2} \cdot n \\
#     T(n) & \in \mathcal{O} \left(n^{1 + \log_4 3} \right) \\
#     \end{align*}
#     $$
#
# #### 3.
#
# >   $$
#     \begin{align*}
#     \\
#     a &= 2 \\
#     b &= 2 \\
#     f(n) &= \mathcal{O}(n) \\
#     \\
#     \text{Da } f(n) & \in \Theta \left(n^{\log_2 2} \right) \text{ , gilt Fall 2:} \\
#     \\
#     T(n) & \in \mathcal{O} \left(n^{\log_2 2} \log n \right) = \mathcal{O}(n \log n)
#     \end{align*}
#     $$
#
# #### 4.
#
# >   $$
#     \begin{align*}
#     \\
#     T(n) &= 2 \cdot T \left( \frac{n}{4} \right) + A \cdot \sqrt{n} \\
#     \\
#     \text{Meistermethode:}
#     \\
#     a &= 2 \\
#     b &= 4 \\
#     f(n) &= A \cdot \sqrt{n}
#     \\
#     \text{Da } f(n) & \in \Theta \left(n^{\log_4 2} \right) = \Theta \left(n^{\frac{1}{2}} \right) \text{ , gilt Fall 2:} \\
#     \\
#     T(n) & \in \Theta \left( \sqrt{n} \log n \right)
#     \end{align*}
#     $$
#
# #### 5.
# >   $$
#     \begin{align*}
#     \\
#     T(n) &= T(n - 1) + T(n - 2) + 1 \\
#     T(n) &> T(n - 2) + T(n - 2) + 1 \\
#     T(n) &> 2 \cdot T(n - 2) + 1 \\
#     T(n) &> 2^{\frac{n}{2}} \\
#     T(n) & \in \Omega(2^{\frac{n}{2}})
#     \end{align*}
#     $$
