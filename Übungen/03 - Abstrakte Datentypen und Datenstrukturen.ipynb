# %% [markdown]
# # Abstrakte Datentypen und Datenstrukturen
#
# #### 1. Linked List
#
# >   a)
#     Implementieren Sie eine Singly Linked List mit *insert* und *remove* Methoden.
#
# >   b)
#     Schreiben Sie eine Prozedur, die Duplikate aus einer Singly Linked List entfernt.
#
# #### 2. Partition
#
# >   a)
#     Schreiben Sie eine Prozedur, die eine Linked List und einen Partitionswert entgegennimmt und eine Linked List zurückgibt, bei der alle Werte, die kleiner als der Partitionswert sind, links von allen Werten, die größer als der Partitionswert sind, sind.
#
# >   __Beispiel:__
#
# >   Eingabe: 1 $\rightarrow$ 6 $\rightarrow$ 3 $\rightarrow$ 8 $\rightarrow$ 2 $\rightarrow$ 5 $\rightarrow$ 7 $\rightarrow$ 5 $\rightarrow$ 9 $\rightarrow$ 10 $\rightarrow$ 2, Partition: 5
#
# >   mögliche Ausgabe: 2 $\rightarrow$ 2 $\rightarrow$ 1 $\rightarrow$ 3 $\rightarrow$ 5 $\rightarrow$ 10 $\rightarrow$ 6 $\rightarrow$ 8 $\rightarrow$ 7 $\rightarrow$ 5 $\rightarrow$ 9
#
# >   Alle Werte kleiner als 5 sind links von allen Werten größer als 5. Die Positionen der 5en spielen keine Rolle.
#
# >   b)
#     Bestimmen Sie die Zeitkomplexität Ihres Algorithmus.
#
# #### 3. Eine Folge von $n$ ganzen Zahlen $p(1), p(2), \dotsc , p(n)$ ist gegeben. Jedes Element der Folge ist verschieden und erfüllt $0 \leqslant p(x) < n$.
#
# >   a)
#     Schreiben Sie einen Algorithmus, der für jedes $x$ mit $0 \leqslant x < n$ eine ganze Zahl $y$ findet, so dass $p(p(y)) = x$.
#
# >   b)
#     Bestimmen Sie die Zeitkomplexität Ihres Algorithmus aus Aufgabe a in Abhängigkeit von der Anzahl $n$ der Elemente der Folge unter der Annahme, dass die Folge in einer Linked List vorliegt.
#
# >   c)
#     Falls der Algorithmus nicht in $\mathcal{O}(n)$ läuft, finden Sie einen Algorithmus, der dies in $\mathcal{O}(n)$ tut.

# %% [markdown]
# 3.

# %%
import doctest


class LinkedList:
    def __init__(self, values):
        if len(values) == 0:
            self.value = None
            self.next = None
        else:
            self.value = values[0]
            self.next = LinkedList(values[1:])

    def __len__(self):
        if self.value is None:
            return 0
        if self.next is None:
            return 1
        return 1 + len(self.next)

    def get(self, index):
        if index == 0:
            return self.value
        return self.next.get(index - 1)


def distinct_sequence_solver(numbers, x):
    """
    :param numbers: Linked list of sequence
    :param x: x-value
    :return: y, so that p(p(y))=x
    
    >>> distinct_sequence_solver(LinkedList([4, 1, 6, 2, 3, 5, 0]), 4)
    6

    >>> distinct_sequence_solver(LinkedList([1, 0, 7, 5, 4, 2, 3, 6]), 2)
    3

    >>> distinct_sequence_solver(LinkedList([1, 0, 7, 5, 4, 2, 3, 6]), 3)
    7

    >>> distinct_sequence_solver(LinkedList([1, 0, 2, 3]), 0)
    0
    """
    # your code goes here, implement the method to make the test cases pass


    
doctest.run_docstring_examples(distinct_sequence_solver, globals())
# Out:
# **********************************************************************
# File "__main__", line 32, in NoName
# Failed example:
#     distinct_sequence_solver(LinkedList([4, 1, 6, 2, 3, 5, 0]), 4)
# Expected:
#     6
# Got nothing
# **********************************************************************
# File "__main__", line 35, in NoName
# Failed example:
#     distinct_sequence_solver(LinkedList([1, 0, 7, 5, 4, 2, 3, 6]), 2)
# Expected:
#     3
# Got nothing
# **********************************************************************
# File "__main__", line 38, in NoName
# Failed example:
#     distinct_sequence_solver(LinkedList([1, 0, 7, 5, 4, 2, 3, 6]), 3)
# Expected:
#     7
# Got nothing
# **********************************************************************
# File "__main__", line 41, in NoName
# Failed example:
#     distinct_sequence_solver(LinkedList([1, 0, 2, 3]), 0)
# Expected:
#     0
# Got nothing
