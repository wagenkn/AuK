# %% [markdown]
# # Hashing und Hash Tables
#
# #### 1. Implementieren Sie eine Hash Table, die intern folgende Hashfunktion verwendet:
#
# >   $$
#     h(k) = (a \cdot k + b) \bmod p \bmod m
#     $$
#
# >   Wählen Sie $a, b \in \{0, 1, \dotsc , p-1 \}$ zufällig. Für $p$ wählen Sie eine Primzahl $> m$. Sie brauchen dabei nicht Table Doubling zu implementieren. $m$ darf also statisch sein.
#
# #### 2. Ein Nachteil von Hashing with Chaining ist die Verschwendung von Speicherplatz bei leeren Slots. Nehmen Sie an, dass uniform zufällig eine Hashfunktion von allen Hashfunktionen gewählt wird (Uniform Hashing).
#
# >   a)
#     Wie groß ist die Wahrscheinlichkeit, dass der $i$-te Slot (ein beliebig ausgewählter Slot) nach dem Einfügen von $n$ Elementen in die Datenstruktur frei ist?
#
# >   b)
#     Geben Sie den Erwartungswert für die Anzahl der freien Plätze in Abhängigkeit von der Slotanzahl $m$ und der Anzahl $n$ an Elementen, die in die Hash Map eingefügt wurden, an.
#
# #### 3. Is Unique
#
# >   a)
#     Implementieren Sie einen Algorithmus, der bestimmt, ob ein String nur Zeichen enthält, die nicht mehrfach vorkommen. Nehmen Sie an, dass im String nur ASCII-Zeichen vorkommen.
#
# >   __Beispiel:__
#
# >   Eingabe: 'Hallo'
#
# >   Ausgabe: __false__
#
# >   , da __l__ doppelt vorkommt
#
# >   b)
#     Bestimmen Sie die Zeitkomplexität Ihres Algorithmus.
#
# #### 4. Permutationsprüfung
#
# >   a)
#     Implementieren Sie einen Algorithmus, der bestimmt, ob zwei Strings Permutationen voneinander sind.
#
# >   __Beispiel:__
#
# >   Eingabe: 'Ampel', 'Lampe'
#
# >   Ausgabe: __true__
#
# >   b)
#     Bestimmen Sie die Zeit- und Speicherkomplexität Ihres Algorithmus.

# %% [markdown]
# 3.

# %%
import doctest


def is_unique(string):
    """
    >>> is_unique('hello')
    False
    >>> is_unique('algorithm')
    True
    >>> is_unique('hashing')
    False
    >>> is_unique('unique')
    False
    >>> is_unique('random')
    True
    """
    # your code goes here, implement the method to make the test cases pass
    
    
    
doctest.run_docstring_examples(is_unique, globals())
# Out:
# **********************************************************************
# File "__main__", line 6, in NoName
# Failed example:
#     is_unique('hello')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 8, in NoName
# Failed example:
#     is_unique('algorithm')
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 10, in NoName
# Failed example:
#     is_unique('hashing')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 12, in NoName
# Failed example:
#     is_unique('unique')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 14, in NoName
# Failed example:
#     is_unique('random')
# Expected:
#     True
# Got nothing

# %% [markdown]
# 4.

# %%
import doctest


def is_permutation(a, b):
    """
    >>> is_permutation('lampe', 'ampel')
    True
    >>> is_permutation('word', 'permutation')
    False
    >>> is_permutation('abcde', 'ebcda')
    True
    >>> is_permutation('random', 'ransom')
    False
    >>> is_permutation('silent', 'listen')
    True
    >>> is_permutation('married', 'admirer')
    True
    >>> is_permutation('algorithm', 'computers')
    False
    >>> is_permutation('wisdom', 'widdow')
    False
    """
    # your code goes here, implement the method to make the test cases pass

    
    
doctest.run_docstring_examples(is_permutation, globals())
# Out:
# **********************************************************************
# File "__main__", line 6, in NoName
# Failed example:
#     is_permutation('lampe', 'ampel')
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 8, in NoName
# Failed example:
#     is_permutation('word', 'permutation')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 10, in NoName
# Failed example:
#     is_permutation('abcde', 'ebcda')
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 12, in NoName
# Failed example:
#     is_permutation('random', 'ransom')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 14, in NoName
# Failed example:
#     is_permutation('silent', 'listen')
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 16, in NoName
# Failed example:
#     is_permutation('married', 'admirer')
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 18, in NoName
# Failed example:
#     is_permutation('algorithm', 'computers')
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 20, in NoName
# Failed example:
#     is_permutation('wisdom', 'widdow')
# Expected:
#     False
# Got nothing
