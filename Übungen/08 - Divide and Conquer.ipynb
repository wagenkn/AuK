# %% [markdown]
# # Divide and Conquer
#
# #### 1. Geben Sie enge asymptotische obere Schranken für $T(n)$ an.
#
# >   a)
# >   $
#     T(n) = 2 \cdot T(\frac{n}{4}) + \sqrt{n}
#     $
#
# >   b)
#     $
#     T(n) = 7 \cdot T(\frac{n}{3}) + n^2
#     $
#
# #### 2. Matrixmultiplikation: $A \times B = C$, wobei es sich bei $A$ und $B$ um zwei $n \times n$ Matrizen handelt.
#
# >   a)
#     Bestimmen Sie den asymptotischen Zeitaufwand eines naïven Algorithmus, der jeden Wert in $C$ durch Multiplikation der Zeilen- und Spaltenvektoren von $A$ und $B$ bestimmt.
#
# >   b)
#     Der Strassen-Algorithmus, der nach dem Divide and Conquer-Prinzip funktioniert, zerlegt das Problem in 7 Teilprobleme der Größe $\frac{n}{2}$. Das Zusammenführen der Lösungen findet mit einem Aufwand von $\Theta(n^2)$ statt. Bestimmen sie die asymptotische Laufzeit des Strassen-Algorithmus und vergleichen Sie die mit der Laufzeit des naïven Ansatz.
#
# #### 3. Innerhalb eines zufällig mit ganzen Zahlen gefüllten Arrays soll das minimale und das maximale Element gefunden werden. Schreiben Sie einen Algorithmus *minMax*, welcher auf dem Divide and Conquer Ansatz basiert. Die größte und die kleinste Zahl des Arrays sollen zurückgegeben werden. Achten Sie darauf, dass die Anzahl der Verlgeichsoperationen möglichst gering sein soll. Als Orientierung können Sie $2(n-1)$ nehmen, dies ist die Anzahl der Vergleiche im normalen Ansatz, bei welchen mann 2-mal durch das Array iteriert.

# %%
import doctest


def minMax(ls):
    """
    >>> minMax([82, 81, 28, 48, 64, 73, 34, 34, 68, 50, 40, 62, 6, 11, 99, 68, 75, 72, 19, 92, 50])
    (6, 99)
    >>> minMax([31, 67, 9, 81, 71, 34, 89, 52, 74, 89])
    (9, 89)
    >>> minMax([27, 95, 4, 79, 11, 96, 26, 64, 100, 41, 78, 48, 99, 100])
    (4, 100)
    >>> minMax([92, 76, 42, 35, 89, 95, 49, 84, 15, 87, 79, 67, 29, 67, 37, 47, 61, 93, 24, 2, 71])
    (2, 95)
    >>> minMax([1, 38, 36, 64, 20, 77, 64, 25, 83, 79, 81, 81, 4, 25, 30])
    (1, 83)
    >>> minMax([48, 32, 16, 87, 7, 80, 58, 56, 98, 80, 45, 54, 82, 84, 5, 51, 40, 69, 31, 45, 82, 33, 76, 59, 56, 2, 60, 80, 17, 81])
    (2, 98)
    >>> minMax([81, 43, 33, 63, 60, 60, 20, 26, 81, 89, 4, 5, 23, 62, 9, 85, 94, 84, 31, 56, 36, 88, 73, 53, 26])
    (4, 94)
    >>> minMax([96, 72, 98, 38, 81, 94, 12, 32, 20, 90, 82, 37, 48, 37, 23, 19, 60, 57, 40, 7, 39, 18, 59, 79, 31, 62, 56, 63, 64, 25])
    (7, 98)
    """
    # your code goes here, implement the method to make the test cases pass
    
    
    
doctest.run_docstring_examples(minMax, globals())
# Out:
# **********************************************************************
# File "__main__", line 6, in NoName
# Failed example:
#     minMax([82, 81, 28, 48, 64, 73, 34, 34, 68, 50, 40, 62, 6, 11, 99, 68, 75, 72, 19, 92, 50])
# Expected:
#     (6, 99)
# Got nothing
# **********************************************************************
# File "__main__", line 8, in NoName
# Failed example:
#     minMax([31, 67, 9, 81, 71, 34, 89, 52, 74, 89])
# Expected:
#     (9, 89)
# Got nothing
# **********************************************************************
# File "__main__", line 10, in NoName
# Failed example:
#     minMax([27, 95, 4, 79, 11, 96, 26, 64, 100, 41, 78, 48, 99, 100])
# Expected:
#     (4, 100)
# Got nothing
# **********************************************************************
# File "__main__", line 12, in NoName
# Failed example:
#     minMax([92, 76, 42, 35, 89, 95, 49, 84, 15, 87, 79, 67, 29, 67, 37, 47, 61, 93, 24, 2, 71])
# Expected:
#     (2, 95)
# Got nothing
# ...
